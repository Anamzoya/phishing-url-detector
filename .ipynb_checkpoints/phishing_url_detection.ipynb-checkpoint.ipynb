# %% [markdown]
# # 🧠 Phishing URL Detection Using Machine Learning
# Detect whether a URL is legitimate or phishing using a Random Forest classifier. This project is created for the Nas Academy AI Program.
#
# 👨🏽‍💻 By: Mohammed Yaseeen Anamzooya Nurudeen

# %% [markdown]
# ## 📌 1. Introduction
#
# Phishing is one of the most common cyber threats today. In this project, we build a machine learning model to classify URLs as either legitimate or phishing. We use a dataset from Kaggle that includes various URL-based features.
#
# **Goal**: Build and evaluate a model to detect phishing URLs with high accuracy.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 📥 2. Load and Explore the Dataset
#
# We load the training and testing datasets, explore the structure, and check for missing values.

# %%
train_df = pd.read_parquet(r"C:\Users\GRACETECH COMPUTERS\Downloads\Compressed\archive_2\Training.parquet")
test_df = pd.read_parquet(r"C:\Users\GRACETECH COMPUTERS\Downloads\Compressed\archive_2\Testing.parquet")

# %%
print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
train_df.head()
# Out:
# Train shape: (7658, 89)
# Test shape: (3772, 89)
#                                                  url  length_url  \
# 0  https://www.todayshomeowner.com/how-to-make-ho...          82
# 1  http://thapthan.ac.th/information/confirmation...          93
# 2  http://app.dialoginsight.com/T/OFC4/L2S/3888/B...         121
# 3                           https://www.bedslide.com          24
# 4  https://tabs.ultimate-guitar.com/s/sex_pistols...          73
#
#    length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  nb_or  ...  \
# 0               23   0        2           7      0      0       0      0  ...
# 1               14   1        2           0      0      0       0      0  ...
# 2               21   1        3           0      0      0       0      0  ...
# 3               16   0        2           0      0      0       0      0  ...
# 4               24   0        3           1      0      0       0      0  ...
#
# ...

# %%
print(train_df.columns)
print(train_df['status'].value_counts())
# Out:
# Index(['url', 'length_url', 'length_hostname', 'ip', 'nb_dots', 'nb_hyphens',
#        'nb_at', 'nb_qm', 'nb_and', 'nb_or', 'nb_eq', 'nb_underscore',
#        'nb_tilde', 'nb_percent', 'nb_slash', 'nb_star', 'nb_colon', 'nb_comma',
#        'nb_semicolumn', 'nb_dollar', 'nb_space', 'nb_www', 'nb_com',
#        'nb_dslash', 'http_in_path', 'https_token', 'ratio_digits_url',
#        'ratio_digits_host', 'punycode', 'port', 'tld_in_path',
#        'tld_in_subdomain', 'abnormal_subdomain', 'nb_subdomains',
#        'prefix_suffix', 'random_domain', 'shortening_service',
#        'path_extension', 'nb_redirection', 'nb_external_redirection',
#        'length_words_raw', 'char_repeat', 'shortest_words_raw',
#        'shortest_word_host', 'shortest_word_path', 'longest_words_raw',
#        'longest_word_host', 'longest_word_path', 'avg_words_raw',
#        'avg_word_host', 'avg_word_path', 'phish_hints', 'domain_in_brand',
#        'brand_in_subdomain', 'brand_in_path', 'suspecious_tld',
# ...

# %% [markdown]
# ## 🧼 3. Preprocessing and Feature Engineering
#
# We select useful features, convert categorical data to numerical if needed, and prepare our data for training.

# %%
import re

def extract_url_features(df):
    df['url_length'] = df['url'].apply(lambda x: len(str(x)))
    df['num_dots'] = df['url'].apply(lambda x: str(x).count('.'))
    df['has_https'] = df['url'].apply(lambda x: 1 if 'https' in str(x) else 0)
    df['num_hyphens'] = df['url'].apply(lambda x: str(x).count('-'))
    df['num_slashes'] = df['url'].apply(lambda x: str(x).count('/'))
    df['has_at_symbol'] = df['url'].apply(lambda x: 1 if '@' in str(x) else 0)

    # Check if URL uses IP address instead of domain
    def has_ip(url):
        try:
            return 1 if re.match(r"https?://(\d{1,3}\.){3}\d{1,3}", str(url)) else 0
        except:
            return 0
    df['has_ip'] = df['url'].apply(has_ip)

    # Check for common shortener services
    def is_shortened(url):
        shorteners = ['bit.ly', 'tinyurl', 'goo.gl', 'ow.ly', 't.co']
        return 1 if any(s in str(url) for s in shorteners) else 0
    df['is_shortened'] = df['url'].apply(is_shortened)

    return df

# %%
# 2. Extract features from URL
train_df = extract_url_features(train_df)
test_df = extract_url_features(test_df)

# 3. Prepare training data
X_train = train_df.drop(['status', 'url'], axis=1)
y_train = train_df['status']

X_test = test_df.drop(['status', 'url'], axis=1)
y_test = test_df['status']

# %% [markdown]
# ## 🚀 4. Model Training
#
# We use a Random Forest Classifier — a powerful and interpretable ensemble method — to train on the data.

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# ## 🧪 5. Model Evaluation
#
# We evaluate our model using accuracy, precision, recall, F1 score, and visualize performance using a confusion matrix and ROC curve.

# %% [markdown]
# ## 📊 6. Visualizing Results
#
# We plot feature importance to understand what features the model relies on most.

# %%
from sklearn.metrics import roc_curve, auc

# Predict probabilities for the 'phishing' class
y_prob = model.predict_proba(X_test)[:, list(model.classes_).index('phishing')]

# Compute ROC curve and AUC with correct positive label
fpr, tpr, thresholds = roc_curve(y_test, y_prob, pos_label='phishing')
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('🧪 ROC Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129514 (\N{TEST TUBE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 📁 7. Conclusion
#
# Our phishing URL detection model achieved strong results. The project demonstrates how machine learning can be used in cybersecurity to help automatically detect malicious content online.

# %% [markdown]
# ## 📎 9. References
#
# - Dataset: https://www.kaggle.com/datasets/hemanthpingali/phishing-url
# - Scikit-learn documentation: https://scikit-learn.org/
